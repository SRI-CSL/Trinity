# %%
# %load_ext autoreload
# %autoreload 2

# %%
import modules.utils as utils
import inference.FRCNN as FRCNN

# %% [markdown]
# #### Load the FRCNN Model

# %%
frcnn = FRCNN.FRCNNModel()
# Out:
# /homes/e34960/anaconda3/envs/patchdiff/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /homes/e34960/anaconda3/envs/patchdiff/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# -------------------------------

# %% [markdown]
# ### FRCNN on given images

# %% [markdown]
# #### Give the path of the images (containing the jpg, png files)

# %% [markdown]
# Benign Images

# %%
folder = "/project/trinity/datasets/PhysicalAttacks/Person/Benign/"
batch_imgs = utils.LoadImages(folder, batchsize=4, scale=0.25)

for imgs_list in batch_imgs:
    _, _, _ = frcnn.inference(imgs_list)
    frcnn.visualize(scoreThreshold = 0.5, numCols=4)

# %% [markdown]
# Adversarial Images

# %%
folder = "/project/trinity/datasets/PhysicalAttacks/Person/Adversarial/"
batch_imgs = utils.LoadImages(folder, batchsize=4, scale=0.25, numImages=8)

for imgs_list in batch_imgs:
    _, _, _ = frcnn.inference(imgs_list)
    frcnn.visualize(scoreThreshold = 0.5, numCols=4)

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# ##### FRCNN on Apricot Dataset

# %%
# Use utils.LoadApricotDataset for loading the apricot images
batch_data = utils.LoadApricotDataset(datasetPath="/project/trinity/datasets/apricot/pub/apricot-mask/dev/data_mask_v2", batchsize=4, numImages=8, shape=(512,512))

for imgs_list, img_masks in batch_data:
    _, _, _ = frcnn.inference(imgs_list)
    frcnn.visualize(scoreThreshold = 0.5, numCols=4)
