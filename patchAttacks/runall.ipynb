# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import main
import modules.utils as utils

# %%
all_imgs, all_detected_patches, all_inpainted_imgs = main.main()
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
utils.VisualizeInpaintedOutputs(all_imgs, all_detected_patches, all_inpainted_imgs)
